# %% [markdown]
# # 4. Evaluation, Scalability and Storytelling
# Combines model metrics, statistical confidence, and scaling outputs.

# %%
import pandas as pd
from pathlib import Path
BASE = Path('..').resolve()
reports = BASE / 'reports'
display(pd.read_csv(reports / 'mllib_model_comparison.csv'))
display(pd.read_csv(reports / 'sklearn_baseline.csv'))
display(pd.read_csv(reports / 'scaling_strong.csv')) if (reports / 'scaling_strong.csv').exists() else print('Run profiler first')

# %%
# Spark UI screenshots should be captured manually and stored under reports/spark_ui/.
# Use these results in Tableau dashboards 1-4 for final storytelling.
